# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-127ab924-6deb-4a89-a7b6-41a11cdf3470" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-127ab924-6deb-4a89-a7b6-41a11cdf3470">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset=pd.read_csv("miniproject.csv")

# %%
dataset.plot(kind='scatter',x='longitude',y='lattitude')
plt.show()

# %%
dataset.plot(kind='scatter',x='longitude',y='lattitude',alpha=0.4,s=dataset['property_size']/100,label='property_size',c='rent_amount',cmap=plt.get_cmap('jet'),colorbar=True,figsize=(16,8))
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.distplot(dataset['property_size'],color='b')
plt.show()
print("property_size-MIN:",dataset['property_size'].min())
print("property_size-MAX:",dataset['property_size'].max())
# Out:
# property_size-MIN: 0
# property_size-MAX: 12000

# %%
dataset.head(5)
# Out:
#    balconies  bathroom  floor  longitude  lattitude  property_size  \
# 0          3         3      3  17.465080  78.340134           2200
# 1          1         2      2  17.320234  78.467766           1200
# 2          3         3      0  17.403649  78.379442           1800
# 3          1         2      2  17.344880  78.543747            750
# 4          2         2      2  17.446463  78.378910           1250
#
#    rent_amount  totalFloor
# 0        28000           5
# 1        15000           2
# 2        16000           3
# 3         9000           2
# 4        32500           5

# %%
"""house price prediction.ipynb
Automatically generated by Colaboratory.
Original file is located at
   https://colab.research.google.com/drive/1nTaK6hzA92hBM8dpulAdGPrlOqVoKLua#scrollTo=CEmom5hyWtp2
"""

from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
df=pd.read_csv('/content/gdrive/MyDrive/miniproject.csv')
# Out:
# Mounted at /content/gdrive

# %%
x=df.drop(['localityId'],axis=1).values
y=df['localityId'].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.33, random_state=0)

# %%
# Importing the function
from sklearn.metrics import accuracy_score

# Initializing the arrays (multiclass case)
y_pred = [0, 2, 1, 3]
y_true = [0, 1, 2, 3]

# Calculating and printing the result
accuracy_score(y_true, y_pred, normalize=False)
# Out:
# 2

# %%
import anvil.server
anvil.server.connect("DFJQQ6A3AS3NE7T6T7M62WI7-N6FKVNJYHQCYRGRS")

# %%
@anvil.server.callable
def predicting_function(localityId):
  x=input('localityId')
  dataset['localityId']==x
  return (dataset[dataset['localityId']])
